# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Paths
TRAIN_PATH = "C:/Users/HP/Downloads/pests dataset/train"
TEST_PATH = "C:/Users/HP/Downloads/pests dataset/test"

# Data generators with stronger augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.25,
    height_shift_range=0.25,
    brightness_range=[0.6, 1.4],
    zoom_range=0.4,
    shear_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)
test_datagen = ImageDataGenerator(rescale=1./255)

# Load datasets with increased image size
train_generator = train_datagen.flow_from_directory(
  TRAIN_PATH,
    target_size=(160, 160),  
    batch_size=32,
    class_mode='categorical'
)

valid_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(160, 160),  
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH, target_size=(160, 160), batch_size=32, class_mode='categorical', shuffle=False
)
# Out:
# Found 6082 images belonging to 18 classes.
# Found 6082 images belonging to 18 classes.
# Found 1266 images belonging to 18 classes.

# %%
# Base model with partial fine-tuning
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(160, 160, 3), include_top=False, weights='imagenet'
)
base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, verbose=1),
    ModelCheckpoint("pest_detection_model.h5", monitor='val_accuracy', save_best_only=True, verbose=1)
]


history = model.fit(
    train_generator,
    epochs=30,
    validation_data=valid_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 191/191 [==============================] - ETA: 0s - loss: 2.3052 - accuracy: 0.3321
# Epoch 1: val_accuracy improved from -inf to 0.57547, saving model to pest_detection_model.h5
# 191/191 [==============================] - 226s 1s/step - loss: 2.3052 - accuracy: 0.3321 - val_loss: 1.5711 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 2/30
# 191/191 [==============================] - ETA: 0s - loss: 1.5267 - accuracy: 0.5572
# Epoch 2: val_accuracy improved from 0.57547 to 0.65209, saving model to pest_detection_model.h5
# 191/191 [==============================] - 165s 865ms/step - loss: 1.5267 - accuracy: 0.5572 - val_loss: 1.2164 - val_accuracy: 0.6521 - lr: 1.0000e-04
# Epoch 3/30
# 191/191 [==============================] - ETA: 0s - loss: 1.2847 - accuracy: 0.6146
# Epoch 3: val_accuracy improved from 0.65209 to 0.68777, saving model to pest_detection_model.h5
# 191/191 [==============================] - 168s 881ms/step - loss: 1.2847 - accuracy: 0.6146 - val_loss: 1.0613 - val_accuracy: 0.6878 - lr: 1.0000e-04
# Epoch 4/30
# 191/191 [==============================] - ETA: 0s - loss: 1.1623 - accuracy: 0.6478
# Epoch 4: val_accuracy improved from 0.68777 to 0.71325, saving model to pest_detection_model.h5
# 191/191 [==============================] - 178s 931ms/step - loss: 1.1623 - accuracy: 0.6478 - val_loss: 0.9734 - val_accuracy: 0.7133 - lr: 1.0000e-04
# Epoch 5/30
# 191/191 [==============================] - ETA: 0s - loss: 1.0893 - accuracy: 0.6666
# Epoch 5: val_accuracy improved from 0.71325 to 0.71440, saving model to pest_detection_model.h5
# 191/191 [==============================] - 162s 849ms/step - loss: 1.0893 - accuracy: 0.6666 - val_loss: 0.9223 - val_accuracy: 0.7144 - lr: 1.0000e-04
# Epoch 6/30
# 191/191 [==============================] - ETA: 0s - loss: 1.0421 - accuracy: 0.6809
# Epoch 6: val_accuracy improved from 0.71440 to 0.72180, saving model to pest_detection_model.h5
# 191/191 [==============================] - 170s 891ms/step - loss: 1.0421 - accuracy: 0.6809 - val_loss: 0.9021 - val_accuracy: 0.7218 - lr: 1.0000e-04
# Epoch 7/30
# 191/191 [==============================] - ETA: 0s - loss: 1.0168 - accuracy: 0.6851
# Epoch 7: val_accuracy improved from 0.72180 to 0.73676, saving model to pest_detection_model.h5
# 191/191 [==============================] - 173s 906ms/step - loss: 1.0168 - accuracy: 0.6851 - val_loss: 0.8529 - val_accuracy: 0.7368 - lr: 1.0000e-04
# Epoch 8/30
# 191/191 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.6998
# Epoch 8: val_accuracy improved from 0.73676 to 0.74597, saving model to pest_detection_model.h5
# 191/191 [==============================] - 161s 847ms/step - loss: 0.9765 - accuracy: 0.6998 - val_loss: 0.8227 - val_accuracy: 0.7460 - lr: 1.0000e-04
# Epoch 9/30
# 191/191 [==============================] - ETA: 0s - loss: 0.9374 - accuracy: 0.7106
# Epoch 9: val_accuracy improved from 0.74597 to 0.74893, saving model to pest_detection_model.h5
# 191/191 [==============================] - 177s 928ms/step - loss: 0.9374 - accuracy: 0.7106 - val_loss: 0.8046 - val_accuracy: 0.7489 - lr: 1.0000e-04
# Epoch 10/30
# 191/191 [==============================] - ETA: 0s - loss: 0.9158 - accuracy: 0.7146
# Epoch 10: val_accuracy did not improve from 0.74893
# 191/191 [==============================] - 175s 918ms/step - loss: 0.9158 - accuracy: 0.7146 - val_loss: 0.7956 - val_accuracy: 0.7458 - lr: 1.0000e-04
# Epoch 11/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8832 - accuracy: 0.7267
# Epoch 11: val_accuracy improved from 0.74893 to 0.76077, saving model to pest_detection_model.h5
# 191/191 [==============================] - 168s 882ms/step - loss: 0.8832 - accuracy: 0.7267 - val_loss: 0.7716 - val_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 12/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8714 - accuracy: 0.7269
# Epoch 12: val_accuracy improved from 0.76077 to 0.76258, saving model to pest_detection_model.h5
# 191/191 [==============================] - 174s 911ms/step - loss: 0.8714 - accuracy: 0.7269 - val_loss: 0.7664 - val_accuracy: 0.7626 - lr: 1.0000e-04
# Epoch 13/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8620 - accuracy: 0.7323
# Epoch 13: val_accuracy improved from 0.76258 to 0.77639, saving model to pest_detection_model.h5
# 191/191 [==============================] - 184s 966ms/step - loss: 0.8620 - accuracy: 0.7323 - val_loss: 0.7223 - val_accuracy: 0.7764 - lr: 1.0000e-04
# Epoch 14/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8516 - accuracy: 0.7382
# Epoch 14: val_accuracy did not improve from 0.77639
# 191/191 [==============================] - 160s 842ms/step - loss: 0.8516 - accuracy: 0.7382 - val_loss: 0.7309 - val_accuracy: 0.7711 - lr: 1.0000e-04
# Epoch 15/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8510 - accuracy: 0.7356
# Epoch 15: val_accuracy did not improve from 0.77639
# 191/191 [==============================] - 171s 900ms/step - loss: 0.8510 - accuracy: 0.7356 - val_loss: 0.7332 - val_accuracy: 0.7692 - lr: 1.0000e-04
# Epoch 16/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8209 - accuracy: 0.7371
# Epoch 16: val_accuracy did not improve from 0.77639
# 191/191 [==============================] - 178s 934ms/step - loss: 0.8209 - accuracy: 0.7371 - val_loss: 0.7108 - val_accuracy: 0.7736 - lr: 1.0000e-04
# Epoch 17/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7870 - accuracy: 0.7507
# Epoch 17: val_accuracy improved from 0.77639 to 0.78593, saving model to pest_detection_model.h5
# 191/191 [==============================] - 162s 848ms/step - loss: 0.7870 - accuracy: 0.7507 - val_loss: 0.7033 - val_accuracy: 0.7859 - lr: 1.0000e-04
# Epoch 18/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7923 - accuracy: 0.7478
# Epoch 18: val_accuracy improved from 0.78593 to 0.79086, saving model to pest_detection_model.h5
# 191/191 [==============================] - 172s 903ms/step - loss: 0.7923 - accuracy: 0.7478 - val_loss: 0.6746 - val_accuracy: 0.7909 - lr: 1.0000e-04
# Epoch 19/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7959 - accuracy: 0.7479
# Epoch 19: val_accuracy improved from 0.79086 to 0.79267, saving model to pest_detection_model.h5
# 191/191 [==============================] - 175s 916ms/step - loss: 0.7959 - accuracy: 0.7479 - val_loss: 0.6712 - val_accuracy: 0.7927 - lr: 1.0000e-04
# Epoch 20/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7564 - accuracy: 0.7576
# Epoch 20: val_accuracy did not improve from 0.79267
# 191/191 [==============================] - 162s 850ms/step - loss: 0.7564 - accuracy: 0.7576 - val_loss: 0.6669 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 21/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7658 - accuracy: 0.7616
# Epoch 21: val_accuracy improved from 0.79267 to 0.79365, saving model to pest_detection_model.h5
# 191/191 [==============================] - 166s 870ms/step - loss: 0.7658 - accuracy: 0.7616 - val_loss: 0.6383 - val_accuracy: 0.7937 - lr: 1.0000e-04
# Epoch 22/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7351 - accuracy: 0.7715
# Epoch 22: val_accuracy improved from 0.79365 to 0.79957, saving model to pest_detection_model.h5
# 191/191 [==============================] - 169s 888ms/step - loss: 0.7351 - accuracy: 0.7715 - val_loss: 0.6474 - val_accuracy: 0.7996 - lr: 1.0000e-04
# Epoch 23/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7335 - accuracy: 0.7655
# Epoch 23: val_accuracy did not improve from 0.79957
# 191/191 [==============================] - 168s 883ms/step - loss: 0.7335 - accuracy: 0.7655 - val_loss: 0.6396 - val_accuracy: 0.7984 - lr: 1.0000e-04
# Epoch 24/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7379 - accuracy: 0.7637
# Epoch 24: val_accuracy did not improve from 0.79957
# 191/191 [==============================] - 170s 892ms/step - loss: 0.7379 - accuracy: 0.7637 - val_loss: 0.6315 - val_accuracy: 0.7976 - lr: 1.0000e-04
# Epoch 25/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.7703
# Epoch 25: val_accuracy improved from 0.79957 to 0.80483, saving model to pest_detection_model.h5
# 191/191 [==============================] - 182s 956ms/step - loss: 0.7230 - accuracy: 0.7703 - val_loss: 0.6178 - val_accuracy: 0.8048 - lr: 1.0000e-04
# Epoch 26/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7024 - accuracy: 0.7770
# Epoch 26: val_accuracy improved from 0.80483 to 0.80598, saving model to pest_detection_model.h5
# 191/191 [==============================] - 164s 858ms/step - loss: 0.7024 - accuracy: 0.7770 - val_loss: 0.6135 - val_accuracy: 0.8060 - lr: 1.0000e-04
# Epoch 27/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7073 - accuracy: 0.7708
# Epoch 27: val_accuracy improved from 0.80598 to 0.80730, saving model to pest_detection_model.h5
# 191/191 [==============================] - 277s 1s/step - loss: 0.7073 - accuracy: 0.7708 - val_loss: 0.6106 - val_accuracy: 0.8073 - lr: 1.0000e-04
# Epoch 28/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.7803
# Epoch 28: val_accuracy improved from 0.80730 to 0.80944, saving model to pest_detection_model.h5
# 191/191 [==============================] - 302s 2s/step - loss: 0.6938 - accuracy: 0.7803 - val_loss: 0.5984 - val_accuracy: 0.8094 - lr: 1.0000e-04
# Epoch 29/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.7795
# Epoch 29: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 288s 2s/step - loss: 0.6812 - accuracy: 0.7795 - val_loss: 0.6022 - val_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 30/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6731 - accuracy: 0.7838
# Epoch 30: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 296s 2s/step - loss: 0.6731 - accuracy: 0.7838 - val_loss: 0.6029 - val_accuracy: 0.8042 - lr: 1.0000e-04

# %%
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])


history_fine = model.fit(
    train_generator,
    epochs=30,
    validation_data=valid_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 191/191 [==============================] - ETA: 0s - loss: 1.0019 - accuracy: 0.6940
# Epoch 1: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 315s 2s/step - loss: 1.0019 - accuracy: 0.6940 - val_loss: 0.6266 - val_accuracy: 0.7999 - lr: 1.0000e-05
# Epoch 2/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8723 - accuracy: 0.7261
# Epoch 2: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 298s 2s/step - loss: 0.8723 - accuracy: 0.7261 - val_loss: 0.6131 - val_accuracy: 0.8006 - lr: 1.0000e-05
# Epoch 3/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.7391
# Epoch 3: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 302s 2s/step - loss: 0.8365 - accuracy: 0.7391 - val_loss: 0.6130 - val_accuracy: 0.8091 - lr: 1.0000e-05
# Epoch 4/30
# 191/191 [==============================] - ETA: 0s - loss: 0.8115 - accuracy: 0.7458
# Epoch 4: val_accuracy did not improve from 0.80944
# 191/191 [==============================] - 328s 2s/step - loss: 0.8115 - accuracy: 0.7458 - val_loss: 0.6037 - val_accuracy: 0.8057 - lr: 1.0000e-05
# Epoch 5/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7905 - accuracy: 0.7509
# Epoch 5: val_accuracy improved from 0.80944 to 0.81437, saving model to pest_detection_model.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.7905 - accuracy: 0.7509 - val_loss: 0.5761 - val_accuracy: 0.8144 - lr: 1.0000e-05
# Epoch 6/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7745 - accuracy: 0.7529
# Epoch 6: val_accuracy did not improve from 0.81437
# 191/191 [==============================] - 149s 780ms/step - loss: 0.7745 - accuracy: 0.7529 - val_loss: 0.5681 - val_accuracy: 0.8144 - lr: 1.0000e-05
# Epoch 7/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7577 - accuracy: 0.7660
# Epoch 7: val_accuracy improved from 0.81437 to 0.81766, saving model to pest_detection_model.h5
# 191/191 [==============================] - 169s 888ms/step - loss: 0.7577 - accuracy: 0.7660 - val_loss: 0.5777 - val_accuracy: 0.8177 - lr: 1.0000e-05
# Epoch 8/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7522 - accuracy: 0.7636
# Epoch 8: val_accuracy improved from 0.81766 to 0.81815, saving model to pest_detection_model.h5
# 191/191 [==============================] - 143s 747ms/step - loss: 0.7522 - accuracy: 0.7636 - val_loss: 0.5704 - val_accuracy: 0.8182 - lr: 1.0000e-05
# Epoch 9/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7179 - accuracy: 0.7657
# Epoch 9: val_accuracy improved from 0.81815 to 0.81865, saving model to pest_detection_model.h5
# 191/191 [==============================] - 158s 830ms/step - loss: 0.7179 - accuracy: 0.7657 - val_loss: 0.5614 - val_accuracy: 0.8186 - lr: 1.0000e-05
# Epoch 10/30
# 191/191 [==============================] - ETA: 0s - loss: 0.7132 - accuracy: 0.7729
# Epoch 10: val_accuracy improved from 0.81865 to 0.82308, saving model to pest_detection_model.h5
# 191/191 [==============================] - 154s 809ms/step - loss: 0.7132 - accuracy: 0.7729 - val_loss: 0.5570 - val_accuracy: 0.8231 - lr: 1.0000e-05
# Epoch 11/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6992 - accuracy: 0.7769
# Epoch 11: val_accuracy improved from 0.82308 to 0.82539, saving model to pest_detection_model.h5
# 191/191 [==============================] - 153s 804ms/step - loss: 0.6992 - accuracy: 0.7769 - val_loss: 0.5521 - val_accuracy: 0.8254 - lr: 1.0000e-05
# Epoch 12/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6826 - accuracy: 0.7741
# Epoch 12: val_accuracy did not improve from 0.82539
# 191/191 [==============================] - 151s 790ms/step - loss: 0.6826 - accuracy: 0.7741 - val_loss: 0.5538 - val_accuracy: 0.8232 - lr: 1.0000e-05
# Epoch 13/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.7846
# Epoch 13: val_accuracy improved from 0.82539 to 0.83246, saving model to pest_detection_model.h5
# 191/191 [==============================] - 171s 895ms/step - loss: 0.6711 - accuracy: 0.7846 - val_loss: 0.5340 - val_accuracy: 0.8325 - lr: 1.0000e-05
# Epoch 14/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.7826
# Epoch 14: val_accuracy did not improve from 0.83246
# 191/191 [==============================] - 156s 821ms/step - loss: 0.6769 - accuracy: 0.7826 - val_loss: 0.5354 - val_accuracy: 0.8310 - lr: 1.0000e-05
# Epoch 15/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.7910
# Epoch 15: val_accuracy did not improve from 0.83246
# 191/191 [==============================] - 142s 746ms/step - loss: 0.6597 - accuracy: 0.7910 - val_loss: 0.5229 - val_accuracy: 0.8264 - lr: 1.0000e-05
# Epoch 16/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6624 - accuracy: 0.7881
# Epoch 16: val_accuracy improved from 0.83246 to 0.83328, saving model to pest_detection_model.h5
# 191/191 [==============================] - 171s 896ms/step - loss: 0.6624 - accuracy: 0.7881 - val_loss: 0.5185 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 17/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.7923
# Epoch 17: val_accuracy improved from 0.83328 to 0.84347, saving model to pest_detection_model.h5
# 191/191 [==============================] - 156s 819ms/step - loss: 0.6594 - accuracy: 0.7923 - val_loss: 0.4983 - val_accuracy: 0.8435 - lr: 1.0000e-05
# Epoch 18/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.8009
# Epoch 18: val_accuracy did not improve from 0.84347
# 191/191 [==============================] - 151s 792ms/step - loss: 0.6182 - accuracy: 0.8009 - val_loss: 0.4976 - val_accuracy: 0.8384 - lr: 1.0000e-05
# Epoch 19/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6194 - accuracy: 0.8025
# Epoch 19: val_accuracy did not improve from 0.84347
# 191/191 [==============================] - 168s 882ms/step - loss: 0.6194 - accuracy: 0.8025 - val_loss: 0.4884 - val_accuracy: 0.8417 - lr: 1.0000e-05
# Epoch 20/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.7938
# Epoch 20: val_accuracy improved from 0.84347 to 0.84561, saving model to pest_detection_model.h5
# 191/191 [==============================] - 141s 741ms/step - loss: 0.6411 - accuracy: 0.7938 - val_loss: 0.4955 - val_accuracy: 0.8456 - lr: 1.0000e-05
# Epoch 21/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.8065
# Epoch 21: val_accuracy improved from 0.84561 to 0.85432, saving model to pest_detection_model.h5
# 191/191 [==============================] - 151s 790ms/step - loss: 0.6018 - accuracy: 0.8065 - val_loss: 0.4667 - val_accuracy: 0.8543 - lr: 1.0000e-05
# Epoch 22/30
# 191/191 [==============================] - ETA: 0s - loss: 0.6118 - accuracy: 0.8043
# Epoch 22: val_accuracy did not improve from 0.85432
# 191/191 [==============================] - 152s 796ms/step - loss: 0.6118 - accuracy: 0.8043 - val_loss: 0.4780 - val_accuracy: 0.8497 - lr: 1.0000e-05
# Epoch 23/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5952 - accuracy: 0.8052
# Epoch 23: val_accuracy did not improve from 0.85432
# 191/191 [==============================] - 141s 738ms/step - loss: 0.5952 - accuracy: 0.8052 - val_loss: 0.4636 - val_accuracy: 0.8504 - lr: 1.0000e-05
# Epoch 24/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5920 - accuracy: 0.8109
# Epoch 24: val_accuracy did not improve from 0.85432
# 191/191 [==============================] - 140s 736ms/step - loss: 0.5920 - accuracy: 0.8109 - val_loss: 0.4467 - val_accuracy: 0.8543 - lr: 1.0000e-05
# Epoch 25/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.8058
# Epoch 25: val_accuracy did not improve from 0.85432
# 191/191 [==============================] - 169s 889ms/step - loss: 0.5964 - accuracy: 0.8058 - val_loss: 0.4682 - val_accuracy: 0.8487 - lr: 1.0000e-05
# Epoch 26/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5759 - accuracy: 0.8085
# Epoch 26: val_accuracy improved from 0.85432 to 0.85465, saving model to pest_detection_model.h5
# 191/191 [==============================] - 141s 737ms/step - loss: 0.5759 - accuracy: 0.8085 - val_loss: 0.4474 - val_accuracy: 0.8547 - lr: 1.0000e-05
# Epoch 27/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.8142
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 27: val_accuracy improved from 0.85465 to 0.85498, saving model to pest_detection_model.h5
# 191/191 [==============================] - 141s 740ms/step - loss: 0.5752 - accuracy: 0.8142 - val_loss: 0.4473 - val_accuracy: 0.8550 - lr: 1.0000e-05
# Epoch 28/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.8157
# Epoch 28: val_accuracy improved from 0.85498 to 0.85580, saving model to pest_detection_model.h5
# 191/191 [==============================] - 162s 848ms/step - loss: 0.5717 - accuracy: 0.8157 - val_loss: 0.4482 - val_accuracy: 0.8558 - lr: 3.0000e-06
# Epoch 29/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5458 - accuracy: 0.8269
# Epoch 29: val_accuracy improved from 0.85580 to 0.85827, saving model to pest_detection_model.h5
# 191/191 [==============================] - 152s 796ms/step - loss: 0.5458 - accuracy: 0.8269 - val_loss: 0.4432 - val_accuracy: 0.8583 - lr: 3.0000e-06
# Epoch 30/30
# 191/191 [==============================] - ETA: 0s - loss: 0.5535 - accuracy: 0.8206
# Epoch 30: val_accuracy improved from 0.85827 to 0.86008, saving model to pest_detection_model.h5
# 191/191 [==============================] - 142s 744ms/step - loss: 0.5535 - accuracy: 0.8206 - val_loss: 0.4364 - val_accuracy: 0.8601 - lr: 3.0000e-06

# %%
loss, acc = model.evaluate(test_generator)
print(f"Test Accuracy: {acc*100:.2f}%")

predictions = model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys())))
# Out:
# 40/40 [==============================] - 11s 278ms/step - loss: 0.5689 - accuracy: 0.8175
# Test Accuracy: 81.75%
# 40/40 [==============================] - 11s 244ms/step
#                  precision    recall  f1-score   support
#
#           Aphid       0.44      0.35      0.39        20
# Colorado beetle       0.85      0.96      0.90        47
#     Gryllotalpa       0.63      0.93      0.75        28
#        Mealybug       0.45      1.00      0.62        37
#        Whitefly       0.86      0.25      0.39        24
#        Wireworm       0.58      1.00      0.73        11
#            ants       0.83      0.97      0.89        99
#            bees       0.88      0.96      0.92        95
#          beetle       0.68      0.53      0.60        85
#    catterpillar       0.90      0.63      0.74       105
#      earthworms       0.84      0.69      0.76        77
#          earwig       0.75      0.61      0.67        76
#     grasshopper       0.80      0.74      0.77        95
#            moth       0.94      0.95      0.95       100
#            slug       0.82      0.79      0.80        75
#           snail       0.95      0.99      0.97        95
#            wasp       0.94      0.94      0.94       106
#          weevil       0.88      0.97      0.92        91
#
#        accuracy                           0.82      1266
#       macro avg       0.78      0.79      0.76      1266
#    weighted avg       0.83      0.82      0.81      1266

# %%
from tensorflow.keras.models import load_model

model = load_model("pest_detection_model.h5")
model.save("pest_detection_model_float32", save_format="tf")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenetv2_1.00_160_input with unsupported characters which will be renamed to mobilenetv2_1_00_160_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pest_detection_model_float32\assets
# INFO:tensorflow:Assets written to: pest_detection_model_float32\assets

# %%
model.save("pest_detection_model_saved")


converter = tf.lite.TFLiteConverter.from_saved_model("pest_detection_model_saved")
converter.target_spec.supported_types = [tf.float32] 
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open("pest_detection_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenetv2_1.00_160_input with unsupported characters which will be renamed to mobilenetv2_1_00_160_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pest_detection_model_saved\assets
# INFO:tensorflow:Assets written to: pest_detection_model_saved\assets

# %%
import os

TRAIN_PATH = "C:/Users/HP/Downloads/pests dataset/train"
class_names = sorted(os.listdir(TRAIN_PATH))

with open(" PEST label.txt", "w") as f:
    for class_name in class_names:
        f.write(class_name + "\n")

print("SAVED")
# Out:
# SAVED
